# %% [markdown]
# # Setup and load data:

# %%
use_pca = False

# %%
# %load_ext autoreload
# %autoreload 2

from functions.functions import *
from functions.plotting import *
from functions.autoencoder i
mport *
from functions.mdn import *
from keras import backend as K
from keras.callbacks import TerminateOnNaN, ModelCheckpoint
from keras.models import model_from_json
from livelossplot.keras import PlotLossesCallback
import livelossplot
import tensorflow as tf
import numpy as np
import os
import glob
from itertools import combinations
import matplotlib
plt.rcParams['animation.ffmpeg_path'] = '/project/hep/demers/mnp3/miniconda3/envs/choreo/bin/ffmpeg' # for using html5 video in Jupyter notebook
print(matplotlib.animation.writers.list()) # check that ffmpeg is loaded. if it's not there, use .to_jshtml() instead of .to_html5_video().
# Out:
# Using TensorFlow backend.
# ['ffmpeg', 'ffmpeg_file', 'imagemagick', 'imagemagick_file', 'html']

# %%
setup_gpus()
# Out:
# GPUs found: 0
# ()

# %%
data = load_data('rnn_data/mariel_*')
# Out:
# Files loaded: ['rnn_data/mariel_betternot_and_retrograde.npy', 'rnn_data/mariel_beyond.npy', 'rnn_data/mariel_chunli.npy', 'rnn_data/mariel_honey.npy', 'rnn_data/mariel_knownbetter.npy', 'rnn_data/mariel_penelope.npy']

# %% [markdown]
# # Check out the real data:

# %%
frame = np.random.randint(0,data.full.X.shape[1]-50)
print("Starting from frame {}...".format(frame))

# HTML(animate(data.full.X[:,frame:,:], frames=100))
HTML(animate(data.selected.X[:,frame:,:], frames=100, edges=data.selected.edges, colors='black'))
# Out:
# Starting from frame 20137...
# <video width="504" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # LSTM + MDN

# %% [markdown]
# Plot the data with x,y centering:

# %%
frame = np.random.randint(0,data.full.X.shape[1]-50)
X = data.selected.X # 15 joints
X = X.swapaxes(0, 1)
X[:,:,0] = X[:,:,0] - np.mean(X[:,:,0], axis=0) + 0.5*np.ones(15)
X[:,:,1] = X[:,:,1] - np.mean(X[:,:,1], axis=0) + 0.5*np.ones(15)
HTML(animate(data.selected.X[:,frame:,:], frames=100, edges=data.selected.edges, colors='black'))
# Out:
# <video width="504" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
if use_pca: 
    X = data.selected.X # 15 joints
    # Average frame-by-frame in (x,y):
    X = X.swapaxes(0, 1)
    X[:,:,0] = X[:,:,0] - np.mean(X[:,:,0], axis=0) + 0.5*np.ones(15)
    X[:,:,1] = X[:,:,1] - np.mean(X[:,:,1], axis=0) + 0.5*np.ones(15)
    X = X.reshape(X.shape[0],X.shape[1]*X.shape[2])

    # PCA time:
    from sklearn.decomposition import PCA
    pca = PCA(.95)
    pca_reduced_data = pca.fit_transform(X)
    print('PCA reduction to a {}-dimensional latent space.'.format(pca_reduced_data.shape[1]))
    print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
    print(pca_reduced_data.shape)
    n_time, n_dims, n_verts  = pca_reduced_data.shape[0], 1, pca_reduced_data.shape[1]
    n_mixes = 6
    look_back = 10

    lstm_mdn = LSTM_MDN(cells = [32,32,32,32], n_verts=n_verts, n_dims=n_dims, n_mixes=n_mixes, look_back=look_back)

    train_X = []
    train_Y = []
    for i in range(look_back, n_time, 1):
        train_X.append( pca_reduced_data[i-look_back:i,:] ) # look_back, verts * dims
        train_Y.append( pca_reduced_data[i,:] ) # verts * dims
    train_X = np.array(train_X) # n_samples, lookback, verts * dims
    train_Y = np.array(train_Y) # n_samples, verts * dims
    
    print(train_X.shape, train_Y.shape)
    lstm_mdn.model.summary()
    
else:
    X = data.selected.X # 15 joints
    n_verts, n_time, n_dims = X.shape
    n_mixes = 3
    look_back = 10

    lstm_mdn = LSTM_MDN(cells = [32,32,32,32], n_verts=n_verts, n_dims=n_dims, n_mixes=n_mixes, look_back=look_back)
    train_X, train_Y = lstm_mdn.prepare_inputs(X, look_back=look_back)
    print(train_X.shape)
    print(train_Y.shape)
    lstm_mdn.model.summary()
# Out:
# (44299, 10, 45)
# (44299, 45)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 10, 45)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 32)            9984
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10, 32)            8320
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# mdn_1 (MDN)                  (None, 32)                4653
# =================================================================
# Total params: 32,333
# Trainable params: 32,333
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save the model architecture: 
model_json = lstm_mdn.model.to_json()
with open("weights/model-lstm.json", "w") as json_file:
    json_file.write(model_json)

# %%
checkpoint_filepath="weights/weights-lstm.h5"
checkpoint = ModelCheckpoint(checkpoint_filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')

# Train the model:
lstm_mdn.model.fit(train_X, train_Y, 
                   epochs=200, 
                   batch_size=256, 
                   shuffle=False, 
                   verbose=1,
                   callbacks=[checkpoint, TerminateOnNaN()])
# Out:
# Epoch 1/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -1.8052 - accuracy: 0.1312
#
# Epoch 00001: accuracy improved from -inf to 0.13118, saving model to weights/weights-lstm.h5
# Epoch 2/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -1.8326 - accuracy: 0.0179
#
# Epoch 00002: accuracy did not improve from 0.13118
# Epoch 3/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -1.8812 - accuracy: 0.0809
#
# Epoch 00003: accuracy did not improve from 0.13118
# Epoch 4/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -1.8410 - accuracy: 0.0527
#
# Epoch 00004: accuracy did not improve from 0.13118
# Epoch 5/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -1.8351 - accuracy: 0.0573
#
# Epoch 00005: accuracy did not improve from 0.13118
# Epoch 6/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -1.8713 - accuracy: 0.0814
#
# Epoch 00006: accuracy did not improve from 0.13118
# Epoch 7/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -1.9230 - accuracy: 0.1128
#
# Epoch 00007: accuracy did not improve from 0.13118
# Epoch 8/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -1.8803 - accuracy: 0.1050
#
# Epoch 00008: accuracy did not improve from 0.13118
# Epoch 9/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -1.9180 - accuracy: 0.1025
#
# Epoch 00009: accuracy did not improve from 0.13118
# Epoch 10/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -1.8674 - accuracy: 0.0985
#
# Epoch 00010: accuracy did not improve from 0.13118
# Epoch 11/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -1.9673 - accuracy: 0.0829
#
# Epoch 00011: accuracy did not improve from 0.13118
# Epoch 12/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -1.9649 - accuracy: 0.1114
#
# Epoch 00012: accuracy did not improve from 0.13118
# Epoch 13/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.0263 - accuracy: 0.1586
#
# Epoch 00013: accuracy improved from 0.13118 to 0.15858, saving model to weights/weights-lstm.h5
# Epoch 14/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -1.9492 - accuracy: 0.0702
#
# Epoch 00014: accuracy did not improve from 0.15858
# Epoch 15/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -1.9628 - accuracy: 0.1995
#
# Epoch 00015: accuracy improved from 0.15858 to 0.19953, saving model to weights/weights-lstm.h5
# Epoch 16/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.0317 - accuracy: 0.1700
#
# Epoch 00016: accuracy did not improve from 0.19953
# Epoch 17/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -1.9832 - accuracy: 0.1120
#
# Epoch 00017: accuracy did not improve from 0.19953
# Epoch 18/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.0624 - accuracy: 0.1425
#
# Epoch 00018: accuracy did not improve from 0.19953
# Epoch 19/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -1.9927 - accuracy: 0.1170
#
# Epoch 00019: accuracy did not improve from 0.19953
# Epoch 20/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -1.9968 - accuracy: 0.1218
#
# Epoch 00020: accuracy did not improve from 0.19953
# Epoch 21/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.0637 - accuracy: 0.1330
#
# Epoch 00021: accuracy did not improve from 0.19953
# Epoch 22/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.0029 - accuracy: 0.1403
#
# Epoch 00022: accuracy did not improve from 0.19953
# Epoch 23/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.0929 - accuracy: 0.1708
#
# Epoch 00023: accuracy did not improve from 0.19953
# Epoch 24/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.0676 - accuracy: 0.2028
#
# Epoch 00024: accuracy improved from 0.19953 to 0.20278, saving model to weights/weights-lstm.h5
# Epoch 25/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.1095 - accuracy: 0.1646
#
# Epoch 00025: accuracy did not improve from 0.20278
# Epoch 26/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.0781 - accuracy: 0.1909
#
# Epoch 00026: accuracy did not improve from 0.20278
# Epoch 27/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.1126 - accuracy: 0.1976
#
# Epoch 00027: accuracy did not improve from 0.20278
# Epoch 28/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.0733 - accuracy: 0.1346
#
# Epoch 00028: accuracy did not improve from 0.20278
# Epoch 29/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.2249 - accuracy: 0.1577
#
# Epoch 00029: accuracy did not improve from 0.20278
# Epoch 30/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.1154 - accuracy: 0.1371
#
# Epoch 00030: accuracy did not improve from 0.20278
# Epoch 31/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.1619 - accuracy: 0.1820
#
# Epoch 00031: accuracy did not improve from 0.20278
# Epoch 32/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.1333 - accuracy: 0.2317
#
# Epoch 00032: accuracy improved from 0.20278 to 0.23170, saving model to weights/weights-lstm.h5
# Epoch 33/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.1253 - accuracy: 0.1516
#
# Epoch 00033: accuracy did not improve from 0.23170
# Epoch 34/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.2060 - accuracy: 0.0517
#
# Epoch 00034: accuracy did not improve from 0.23170
# Epoch 35/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.2088 - accuracy: 0.1946
#
# Epoch 00035: accuracy did not improve from 0.23170
# Epoch 36/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.1086 - accuracy: 0.1848
#
# Epoch 00036: accuracy did not improve from 0.23170
# Epoch 37/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.1318 - accuracy: 0.1544
#
# Epoch 00037: accuracy did not improve from 0.23170
# Epoch 38/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.1814 - accuracy: 0.1168
#
# Epoch 00038: accuracy did not improve from 0.23170
# Epoch 39/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.2653 - accuracy: 0.1226
#
# Epoch 00039: accuracy did not improve from 0.23170
# Epoch 40/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.1462 - accuracy: 0.1721
#
# Epoch 00040: accuracy did not improve from 0.23170
# Epoch 41/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.3167 - accuracy: 0.1950
#
# Epoch 00041: accuracy did not improve from 0.23170
# Epoch 42/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.2272 - accuracy: 0.0828
#
# Epoch 00042: accuracy did not improve from 0.23170
# Epoch 43/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.1946 - accuracy: 0.1039
#
# Epoch 00043: accuracy did not improve from 0.23170
# Epoch 44/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.2586 - accuracy: 0.1698
#
# Epoch 00044: accuracy did not improve from 0.23170
# Epoch 45/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3026 - accuracy: 0.1519
#
# Epoch 00045: accuracy did not improve from 0.23170
# Epoch 46/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.2426 - accuracy: 0.1350
#
# Epoch 00046: accuracy did not improve from 0.23170
# Epoch 47/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.1993 - accuracy: 0.2171
#
# Epoch 00047: accuracy did not improve from 0.23170
# Epoch 48/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.2653 - accuracy: 0.1597
#
# Epoch 00048: accuracy did not improve from 0.23170
# Epoch 49/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.2643 - accuracy: 0.0767
#
# Epoch 00049: accuracy did not improve from 0.23170
# Epoch 50/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.2427 - accuracy: 0.1271
#
# Epoch 00050: accuracy did not improve from 0.23170
# Epoch 51/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.2615 - accuracy: 0.1322
#
# Epoch 00051: accuracy did not improve from 0.23170
# Epoch 52/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.2409 - accuracy: 0.1156
#
# Epoch 00052: accuracy did not improve from 0.23170
# Epoch 53/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.2675 - accuracy: 0.2127
#
# Epoch 00053: accuracy did not improve from 0.23170
# Epoch 54/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.3710 - accuracy: 0.1841
#
# Epoch 00054: accuracy did not improve from 0.23170
# Epoch 55/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.3194 - accuracy: 0.1633
#
# Epoch 00055: accuracy did not improve from 0.23170
# Epoch 56/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.2606 - accuracy: 0.1562
#
# Epoch 00056: accuracy did not improve from 0.23170
# Epoch 57/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3241 - accuracy: 0.1400
#
# Epoch 00057: accuracy did not improve from 0.23170
# Epoch 58/200
# 44299/44299 [==============================] - 9s 212us/step - loss: -2.3034 - accuracy: 0.1152
#
# Epoch 00058: accuracy did not improve from 0.23170
# Epoch 59/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3046 - accuracy: 0.1938
#
# Epoch 00059: accuracy did not improve from 0.23170
# Epoch 60/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.3065 - accuracy: 0.1278
#
# Epoch 00060: accuracy did not improve from 0.23170
# Epoch 61/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.3628 - accuracy: 0.1026
#
# Epoch 00061: accuracy did not improve from 0.23170
# Epoch 62/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.2891 - accuracy: 0.1656
#
# Epoch 00062: accuracy did not improve from 0.23170
# Epoch 63/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.3301 - accuracy: 0.0900
#
# Epoch 00063: accuracy did not improve from 0.23170
# Epoch 64/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.3177 - accuracy: 0.1013
#
# Epoch 00064: accuracy did not improve from 0.23170
# Epoch 65/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.3128 - accuracy: 0.1325
#
# Epoch 00065: accuracy did not improve from 0.23170
# Epoch 66/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3936 - accuracy: 0.1219
#
# Epoch 00066: accuracy did not improve from 0.23170
# Epoch 67/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.3807 - accuracy: 0.1320
#
# Epoch 00067: accuracy did not improve from 0.23170
# Epoch 68/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3536 - accuracy: 0.1218
#
# Epoch 00068: accuracy did not improve from 0.23170
# Epoch 69/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.2930 - accuracy: 0.1485
#
# Epoch 00069: accuracy did not improve from 0.23170
# Epoch 70/200
# 44299/44299 [==============================] - 10s 232us/step - loss: -2.3531 - accuracy: 0.0197
#
# Epoch 00070: accuracy did not improve from 0.23170
# Epoch 71/200
# 44299/44299 [==============================] - 11s 237us/step - loss: -2.3749 - accuracy: 0.1225
#
# Epoch 00071: accuracy did not improve from 0.23170
# Epoch 72/200
# 44299/44299 [==============================] - 11s 247us/step - loss: -2.3377 - accuracy: 0.1194
#
# Epoch 00072: accuracy did not improve from 0.23170
# Epoch 73/200
# 44299/44299 [==============================] - 10s 228us/step - loss: -2.2594 - accuracy: 0.0526
#
# Epoch 00073: accuracy did not improve from 0.23170
# Epoch 74/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.3670 - accuracy: 0.0986
#
# Epoch 00074: accuracy did not improve from 0.23170
# Epoch 75/200
# 44299/44299 [==============================] - 10s 216us/step - loss: -2.3761 - accuracy: 0.0957
#
# Epoch 00075: accuracy did not improve from 0.23170
# Epoch 76/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.3728 - accuracy: 0.1189
#
# Epoch 00076: accuracy did not improve from 0.23170
# Epoch 77/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.4303 - accuracy: 0.1125
#
# Epoch 00077: accuracy did not improve from 0.23170
# Epoch 78/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.4062 - accuracy: 0.1131
#
# Epoch 00078: accuracy did not improve from 0.23170
# Epoch 79/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.4073 - accuracy: 0.1318
#
# Epoch 00079: accuracy did not improve from 0.23170
# Epoch 80/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.4199 - accuracy: 0.1798
#
# Epoch 00080: accuracy did not improve from 0.23170
# Epoch 81/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.3615 - accuracy: 0.0698
#
# Epoch 00081: accuracy did not improve from 0.23170
# Epoch 82/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.3636 - accuracy: 0.0638
#
# Epoch 00082: accuracy did not improve from 0.23170
# Epoch 83/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3900 - accuracy: 0.0504
#
# Epoch 00083: accuracy did not improve from 0.23170
# Epoch 84/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.3877 - accuracy: 0.1167
#
# Epoch 00084: accuracy did not improve from 0.23170
# Epoch 85/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.4242 - accuracy: 0.0604
#
# Epoch 00085: accuracy did not improve from 0.23170
# Epoch 86/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.4891 - accuracy: 0.1172
#
# Epoch 00086: accuracy did not improve from 0.23170
# Epoch 87/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.4277 - accuracy: 0.1304
#
# Epoch 00087: accuracy did not improve from 0.23170
# Epoch 88/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.4304 - accuracy: 0.1185
#
# Epoch 00088: accuracy did not improve from 0.23170
# Epoch 89/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5294 - accuracy: 0.1333
#
# Epoch 00089: accuracy did not improve from 0.23170
# Epoch 90/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.4154 - accuracy: 0.1255
#
# Epoch 00090: accuracy did not improve from 0.23170
# Epoch 91/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.4869 - accuracy: 0.1406
#
# Epoch 00091: accuracy did not improve from 0.23170
# Epoch 92/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.4454 - accuracy: 0.1692
#
# Epoch 00092: accuracy did not improve from 0.23170
# Epoch 93/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.5331 - accuracy: 0.1635
#
# Epoch 00093: accuracy did not improve from 0.23170
# Epoch 94/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.5116 - accuracy: 0.0916
#
# Epoch 00094: accuracy did not improve from 0.23170
# Epoch 95/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.4583 - accuracy: 0.1049
#
# Epoch 00095: accuracy did not improve from 0.23170
# Epoch 96/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.4981 - accuracy: 0.1296
#
# Epoch 00096: accuracy did not improve from 0.23170
# Epoch 97/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.5826 - accuracy: 0.1802
#
# Epoch 00097: accuracy did not improve from 0.23170
# Epoch 98/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.4866 - accuracy: 0.1551
#
# Epoch 00098: accuracy did not improve from 0.23170
# Epoch 99/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6053 - accuracy: 0.2159
#
# Epoch 00099: accuracy did not improve from 0.23170
# Epoch 100/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5501 - accuracy: 0.1986
#
# Epoch 00100: accuracy did not improve from 0.23170
# Epoch 101/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5173 - accuracy: 0.1195
#
# Epoch 00101: accuracy did not improve from 0.23170
# Epoch 102/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.4558 - accuracy: 0.1122
#
# Epoch 00102: accuracy did not improve from 0.23170
# Epoch 103/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5690 - accuracy: 0.1779
#
# Epoch 00103: accuracy did not improve from 0.23170
# Epoch 104/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.4535 - accuracy: 0.2189
#
# Epoch 00104: accuracy did not improve from 0.23170
# Epoch 105/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5659 - accuracy: 0.1158
#
# Epoch 00105: accuracy did not improve from 0.23170
# Epoch 106/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5545 - accuracy: 0.1554
#
# Epoch 00106: accuracy did not improve from 0.23170
# Epoch 107/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5399 - accuracy: 0.1885
#
# Epoch 00107: accuracy did not improve from 0.23170
# Epoch 108/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.5722 - accuracy: 0.1700
#
# Epoch 00108: accuracy did not improve from 0.23170
# Epoch 109/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.4721 - accuracy: 0.1742
#
# Epoch 00109: accuracy did not improve from 0.23170
# Epoch 110/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6370 - accuracy: 0.2093
#
# Epoch 00110: accuracy did not improve from 0.23170
# Epoch 111/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5631 - accuracy: 0.2055
#
# Epoch 00111: accuracy did not improve from 0.23170
# Epoch 112/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5265 - accuracy: 0.1868
#
# Epoch 00112: accuracy did not improve from 0.23170
# Epoch 113/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6264 - accuracy: 0.2110
#
# Epoch 00113: accuracy did not improve from 0.23170
# Epoch 114/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5534 - accuracy: 0.2354
#
# Epoch 00114: accuracy improved from 0.23170 to 0.23542, saving model to weights/weights-lstm.h5
# Epoch 115/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6519 - accuracy: 0.1016
#
# Epoch 00115: accuracy did not improve from 0.23542
# Epoch 116/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5050 - accuracy: 0.1591
#
# Epoch 00116: accuracy did not improve from 0.23542
# Epoch 117/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.5949 - accuracy: 0.1828
#
# Epoch 00117: accuracy did not improve from 0.23542
# Epoch 118/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.5820 - accuracy: 0.2662
#
# Epoch 00118: accuracy improved from 0.23542 to 0.26617, saving model to weights/weights-lstm.h5
# Epoch 119/200
# 44299/44299 [==============================] - 10s 237us/step - loss: -2.6365 - accuracy: 0.2639
#
# Epoch 00119: accuracy did not improve from 0.26617
# Epoch 120/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5658 - accuracy: 0.2058
#
# Epoch 00120: accuracy did not improve from 0.26617
# Epoch 121/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5624 - accuracy: 0.2259
#
# Epoch 00121: accuracy did not improve from 0.26617
# Epoch 122/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5961 - accuracy: 0.2205
#
# Epoch 00122: accuracy did not improve from 0.26617
# Epoch 123/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.5382 - accuracy: 0.2127
#
# Epoch 00123: accuracy did not improve from 0.26617
# Epoch 124/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6080 - accuracy: 0.2161
#
# Epoch 00124: accuracy did not improve from 0.26617
# Epoch 125/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6319 - accuracy: 0.2474
#
# Epoch 00125: accuracy did not improve from 0.26617
# Epoch 126/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6361 - accuracy: 0.2086
#
# Epoch 00126: accuracy did not improve from 0.26617
# Epoch 127/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6850 - accuracy: 0.2528
#
# Epoch 00127: accuracy did not improve from 0.26617
# Epoch 128/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6300 - accuracy: 0.2389
#
# Epoch 00128: accuracy did not improve from 0.26617
# Epoch 129/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6621 - accuracy: 0.1509
#
# Epoch 00129: accuracy did not improve from 0.26617
# Epoch 130/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6754 - accuracy: 0.2735
#
# Epoch 00130: accuracy improved from 0.26617 to 0.27348, saving model to weights/weights-lstm.h5
# Epoch 131/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.5107 - accuracy: 0.2506
#
# Epoch 00131: accuracy did not improve from 0.27348
# Epoch 132/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6174 - accuracy: 0.1885
#
# Epoch 00132: accuracy did not improve from 0.27348
# Epoch 133/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6675 - accuracy: 0.1832
#
# Epoch 00133: accuracy did not improve from 0.27348
# Epoch 134/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.5516 - accuracy: 0.1607
#
# Epoch 00134: accuracy did not improve from 0.27348
# Epoch 135/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.6421 - accuracy: 0.2188
#
# Epoch 00135: accuracy did not improve from 0.27348
# Epoch 136/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6508 - accuracy: 0.3107
#
# Epoch 00136: accuracy improved from 0.27348 to 0.31068, saving model to weights/weights-lstm.h5
# Epoch 137/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6754 - accuracy: 0.3045
#
# Epoch 00137: accuracy did not improve from 0.31068
# Epoch 138/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.5849 - accuracy: 0.2120
#
# Epoch 00138: accuracy did not improve from 0.31068
# Epoch 139/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6563 - accuracy: 0.1950
#
# Epoch 00139: accuracy did not improve from 0.31068
# Epoch 140/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6052 - accuracy: 0.2292
#
# Epoch 00140: accuracy did not improve from 0.31068
# Epoch 141/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.7048 - accuracy: 0.2333
#
# Epoch 00141: accuracy did not improve from 0.31068
# Epoch 142/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7465 - accuracy: 0.2464
#
# Epoch 00142: accuracy did not improve from 0.31068
# Epoch 143/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6280 - accuracy: 0.1333
#
# Epoch 00143: accuracy did not improve from 0.31068
# Epoch 144/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6376 - accuracy: 0.1626
#
# Epoch 00144: accuracy did not improve from 0.31068
# Epoch 145/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7166 - accuracy: 0.1598
#
# Epoch 00145: accuracy did not improve from 0.31068
# Epoch 146/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6645 - accuracy: 0.3016
#
# Epoch 00146: accuracy did not improve from 0.31068
# Epoch 147/200
# 44299/44299 [==============================] - 12s 274us/step - loss: -2.5739 - accuracy: 0.2405
#
# Epoch 00147: accuracy did not improve from 0.31068
# Epoch 148/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6617 - accuracy: 0.0862
#
# Epoch 00148: accuracy did not improve from 0.31068
# Epoch 149/200
# 44299/44299 [==============================] - 9s 214us/step - loss: -2.6855 - accuracy: 0.1582
#
# Epoch 00149: accuracy did not improve from 0.31068
# Epoch 150/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7380 - accuracy: 0.1842
#
# Epoch 00150: accuracy did not improve from 0.31068
# Epoch 151/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.7438 - accuracy: 0.1896
#
# Epoch 00151: accuracy did not improve from 0.31068
# Epoch 152/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6818 - accuracy: 0.1390
#
# Epoch 00152: accuracy did not improve from 0.31068
# Epoch 153/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.6942 - accuracy: 0.1965
#
# Epoch 00153: accuracy did not improve from 0.31068
# Epoch 154/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.6723 - accuracy: 0.2164
#
# Epoch 00154: accuracy did not improve from 0.31068
# Epoch 155/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6882 - accuracy: 0.2405
#
# Epoch 00155: accuracy did not improve from 0.31068
# Epoch 156/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7315 - accuracy: 0.1684
#
# Epoch 00156: accuracy did not improve from 0.31068
# Epoch 157/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.7574 - accuracy: 0.2151
#
# Epoch 00157: accuracy did not improve from 0.31068
# Epoch 158/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7190 - accuracy: 0.2345
#
# Epoch 00158: accuracy did not improve from 0.31068
# Epoch 159/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.6910 - accuracy: 0.1282
#
# Epoch 00159: accuracy did not improve from 0.31068
# Epoch 160/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7246 - accuracy: 0.1449
#
# Epoch 00160: accuracy did not improve from 0.31068
# Epoch 161/200
# 44299/44299 [==============================] - 9s 212us/step - loss: -2.5884 - accuracy: 0.1912
#
# Epoch 00161: accuracy did not improve from 0.31068
# Epoch 162/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7897 - accuracy: 0.1546
#
# Epoch 00162: accuracy did not improve from 0.31068
# Epoch 163/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.6933 - accuracy: 0.1883
#
# Epoch 00163: accuracy did not improve from 0.31068
# Epoch 164/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.6728 - accuracy: 0.1722
#
# Epoch 00164: accuracy did not improve from 0.31068
# Epoch 165/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.6825 - accuracy: 0.1247
#
# Epoch 00165: accuracy did not improve from 0.31068
# Epoch 166/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7617 - accuracy: 0.1272
#
# Epoch 00166: accuracy did not improve from 0.31068
# Epoch 167/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7560 - accuracy: 0.1808
#
# Epoch 00167: accuracy did not improve from 0.31068
# Epoch 168/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6390 - accuracy: 0.2216
#
# Epoch 00168: accuracy did not improve from 0.31068
# Epoch 169/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.6973 - accuracy: 0.1894
#
# Epoch 00169: accuracy did not improve from 0.31068
# Epoch 170/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.7484 - accuracy: 0.1966
#
# Epoch 00170: accuracy did not improve from 0.31068
# Epoch 171/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7415 - accuracy: 0.2018
#
# Epoch 00171: accuracy did not improve from 0.31068
# Epoch 172/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.7957 - accuracy: 0.2385
#
# Epoch 00172: accuracy did not improve from 0.31068
# Epoch 173/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7737 - accuracy: 0.2393
#
# Epoch 00173: accuracy did not improve from 0.31068
# Epoch 174/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.7726 - accuracy: 0.2408
#
# Epoch 00174: accuracy did not improve from 0.31068
# Epoch 175/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7234 - accuracy: 0.2360
#
# Epoch 00175: accuracy did not improve from 0.31068
# Epoch 176/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7731 - accuracy: 0.1756
#
# Epoch 00176: accuracy did not improve from 0.31068
# Epoch 177/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7324 - accuracy: 0.2385
#
# Epoch 00177: accuracy did not improve from 0.31068
# Epoch 178/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.7623 - accuracy: 0.2551
#
# Epoch 00178: accuracy did not improve from 0.31068
# Epoch 179/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.6851 - accuracy: 0.1322
#
# Epoch 00179: accuracy did not improve from 0.31068
# Epoch 180/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.7412 - accuracy: 0.1980
#
# Epoch 00180: accuracy did not improve from 0.31068
# Epoch 181/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7265 - accuracy: 0.2183
#
# Epoch 00181: accuracy did not improve from 0.31068
# Epoch 182/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.8066 - accuracy: 0.1837
#
# Epoch 00182: accuracy did not improve from 0.31068
# Epoch 183/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.7665 - accuracy: 0.1868
#
# Epoch 00183: accuracy did not improve from 0.31068
# Epoch 184/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7081 - accuracy: 0.1955
#
# Epoch 00184: accuracy did not improve from 0.31068
# Epoch 185/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.6748 - accuracy: 0.3154
#
# Epoch 00185: accuracy improved from 0.31068 to 0.31536, saving model to weights/weights-lstm.h5
# Epoch 186/200
# 44299/44299 [==============================] - 9s 211us/step - loss: -2.8082 - accuracy: 0.2244
#
# Epoch 00186: accuracy did not improve from 0.31536
# Epoch 187/200
# 44299/44299 [==============================] - 9s 210us/step - loss: -2.7932 - accuracy: 0.2268
#
# Epoch 00187: accuracy did not improve from 0.31536
# Epoch 188/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.8132 - accuracy: 0.2827
#
# Epoch 00188: accuracy did not improve from 0.31536
# Epoch 189/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.7934 - accuracy: 0.2259
#
# Epoch 00189: accuracy did not improve from 0.31536
# Epoch 190/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7731 - accuracy: 0.2271
#
# Epoch 00190: accuracy did not improve from 0.31536
# Epoch 191/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7213 - accuracy: 0.2608
#
# Epoch 00191: accuracy did not improve from 0.31536
# Epoch 192/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.7484 - accuracy: 0.1507
#
# Epoch 00192: accuracy did not improve from 0.31536
# Epoch 193/200
# 44299/44299 [==============================] - 9s 208us/step - loss: -2.8184 - accuracy: 0.1915
#
# Epoch 00193: accuracy did not improve from 0.31536
# Epoch 194/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.8235 - accuracy: 0.2233
#
# Epoch 00194: accuracy did not improve from 0.31536
# Epoch 195/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.7764 - accuracy: 0.1500
#
# Epoch 00195: accuracy did not improve from 0.31536
# Epoch 196/200
# 44299/44299 [==============================] - 9s 209us/step - loss: -2.8037 - accuracy: 0.2086
#
# Epoch 00196: accuracy did not improve from 0.31536
# Epoch 197/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.8047 - accuracy: 0.2615
#
# Epoch 00197: accuracy did not improve from 0.31536
# Epoch 198/200
# 44299/44299 [==============================] - 9s 207us/step - loss: -2.8603 - accuracy: 0.2535
#
# Epoch 00198: accuracy did not improve from 0.31536
# Epoch 199/200

# %%
trained_model = lstm_mdn

# %% [markdown]
# ### Load a trained model + weights

# %%
trained_model = model_from_json(open('weights/model-lstm.json').read(), custom_objects={'MDN': MDN, 'LSTM_MDN': LSTM_MDN})
trained_model.load_weights('weights/weights-lstm.h5')
trained_model.summary()

n_mixes = 3
look_back = 10

if use_pca:
    means = np.load('pca/rnn_pca_32-means.npy')
    components = np.load('pca/rnn_pca_32-components.npy')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-833963546996> in <module>
#       1 trained_model = model_from_json(open('weights/model-lstm.json').read(), custom_objects={'MDN': MDN, 'LSTM_MDN': LSTM_MDN})
# ----> 2 trained_model.load_weights('weights/weights-lstm.h5')
#       3 trained_model.summary()
#       4
#       5 n_mixes = 3
#
# /project/hep/demers/mnp3/miniconda3/envs/choreo2020/lib/python3.7/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /project/hep/demers/mnp3/miniconda3/envs/choreo2020/lib/python3.7/site-packages/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch, reshape)
#    1228             else:
#    1229                 saving.load_weights_from_hdf5_group(
# -> 1230                     f, self.layers, reshape=reshape)
#    1231             if hasattr(f, 'close'):
#    1232                 f.close()
#
# /project/hep/demers/mnp3/miniconda3/envs/choreo2020/lib/python3.7/site-packages/keras/engine/saving.py in load_weights_from_hdf5_group(f, layers, reshape)
#    1199     for name in layer_names:
#    1200         g = f[name]
# -> 1201         weight_names = load_attributes_from_hdf5_group(g, 'weight_names')
#    1202         if weight_names:
#    1203             filtered_layer_names.append(name)
#
# /project/hep/demers/mnp3/miniconda3/envs/choreo2020/lib/python3.7/site-packages/keras/engine/saving.py in load_attributes_from_hdf5_group(group, name)
#     720     """
#     721     if name in group.attrs:
# --> 722         data = [n.decode('utf8') for n in group.attrs[name]]
#     723     else:
#     724         data = []
#
# /project/hep/demers/mnp3/miniconda3/envs/choreo2020/lib/python3.7/site-packages/keras/engine/saving.py in <listcomp>(.0)
#     720     """
#     721     if name in group.attrs:
# --> 722         data = [n.decode('utf8') for n in group.attrs[name]]
#     723     else:
#     724         data = []
#
# AttributeError: 'str' object has no attribute 'decode'

# %% [markdown]
# ### See how well the model can predict the next frame in the input sequence:

# %%
# visualize how well the model learned the input sequence
n_frames = 100 # n frames of time slices to generate
output_dims = train_X.shape[2]
frame = np.random.randint(0,data.full.X.shape[1]-50)
print("Seeding with frame {}".format(frame))
frames = []

test_X = train_X[frame:frame+n_frames] # data to pass into forward prop through the model
y_pred = trained_model.model.predict(test_X) # output with shape (n_frames, (output_dims+2) * n_mixes )

# partition out the mus, sigs, and mixture weights
for i in range(n_frames):
    y = y_pred[i].squeeze()
    mus = y[:n_mixes*output_dims]
    sigs = y[n_mixes*output_dims:n_mixes*output_dims + n_mixes]
    alphas = y[-n_mixes:]
    # find the most likely distribution - then disregard that number and use the first Gaussian :)
    alpha_idx = np.argmax(alphas)
    alpha_idx = 0
    # pull out the mus that correspond to the selected alpha index
    positions = mus[alpha_idx * output_dims:(alpha_idx+1) * output_dims]
    frames.append(positions)

if use_pca:
    # With PCA:
    frames = np.dot(frames, components) + means
    print(frames.shape)
    lstm_predictions = frames.swapaxes(0,1)
    lstm_predictions = np.dstack((lstm_predictions[::3,:],lstm_predictions[1::3,:],lstm_predictions[2::3,:]))
else:
    # No PCA:
    frames = np.array(frames)
    lstm_predictions = np.dstack((frames.T[::3,:],frames.T[1::3,:],frames.T[2::3,:]))
    
HTML(animate_ghost(data.selected.X[:,frame:,:], lstm_predictions[:,:,:], frames=n_frames, edges=data.selected.edges, colors='blue', ghost_shift = 0.3))
# Out:
# Seeding with frame 7103
# <video width="504" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Now generate new sequences!

# %%
n_frames = 128 # n frames of time slices to generate
frames = []
seed = np.random.randint(0, len(train_X)-1)
x = np.expand_dims(train_X[seed], axis=0)
print(' * seeding with', seed)

for i in range(n_frames):
    y = trained_model.model.predict(x).squeeze()
    mus = y[:n_mixes*output_dims]
    sigs = y[n_mixes*output_dims:-n_mixes]
    alphas = softmax(y[-n_mixes:])

    # select the alpha channel to use
    alpha_idx = np.argmax(alphas)

    # grab the mus and sigs associated with the selected alpha_idx
    frame_mus = mus.ravel()[alpha_idx*output_dims : (alpha_idx+1)*output_dims]
    frame_sig = sigs[alpha_idx] / 100

    # now sample from each Gaussian
    positions = [np.random.normal(loc=m, scale=frame_sig) for m in frame_mus]
    positions = frame_mus

    # add these positions to the results
    frames.append(positions)

    # pull out a new training example - stack the new result on
    # all values after the first from the bottom-most value in the x's
    start = x[:,1:,:]
    end = np.expand_dims( np.expand_dims(positions, axis=0), axis=0 )
    x = np.concatenate((start, end), axis=1)
    
frames = np.array(frames)

if use_pca:
    # With PCA:
    frames = np.dot(frames, components) + means
#     print(frames.shape)
    lstm_predictions = frames.swapaxes(0,1)
    lstm_predictions = np.dstack((lstm_predictions[::3,:],lstm_predictions[1::3,:],lstm_predictions[2::3,:]))
else:
    # No PCA:
    lstm_predictions = np.dstack((frames.T[::3,:],frames.T[1::3,:],frames.T[2::3,:]))
    
prompt_plus_generated_seq = np.concatenate((data.selected.X[:,seed:seed+look_back,:],lstm_predictions), axis=1)
HTML(animate_ghost(data.selected.X[:,seed:seed+look_back+n_frames:,:], prompt_plus_generated_seq, frames=look_back+n_frames, edges=data.selected.edges, colors='blue'))
# Out:
#  * seeding with 16898
# <video width="504" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
HTML(animate(lstm_predictions, frames=n_frames, edges=data.selected.edges, colors='blue'))
# Out:
# <video width="504" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...
